# %% [markdown]
# <a href="https://colab.research.google.com/github/nt189/Entendimiento-de-los-Datos-/blob/main/Actividad_2_3_(Evaluacion)/Actividad_2_3_(Evaluacion).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('listings.csv')

# %%
regunc = df['host_name'].drop_duplicates().head(5)
filtro_1 = df[df['host_name'].isin(regunc)]
filtro_1
# Out:
#                         id                                       listing_url  \
# 0       670339032744709144   https://www.airbnb.com/rooms/670339032744709144
# 1                 37014494             https://www.airbnb.com/rooms/37014494
# 2      1024835174766068422  https://www.airbnb.com/rooms/1024835174766068422
# 3       850744632375448560   https://www.airbnb.com/rooms/850744632375448560
# 4       953950676345326970   https://www.airbnb.com/rooms/953950676345326970
# ...                    ...                                               ...
# 44442  1201891252333403929  https://www.airbnb.com/rooms/1201891252333403929
# 44650   665940435763156382   https://www.airbnb.com/rooms/665940435763156382
# 44937   867420953649397156   https://www.airbnb.com/rooms/867420953649397156
# 45411   984374186485707960   https://www.airbnb.com/rooms/984374186485707960
# 45525   889361677833868590   https://www.airbnb.com/rooms/889361677833868590
#
# ...

# %%
filtro_2 =

# %%
filtro_3 = df[df['host_response_time'] == 'within a day']
filtro_3

# %%
filtro_4 = df[df['accommodates'] >= 5]
filtro_4

# %%
filtro_5 = df[(df['room_type'] == 'Entire home') | (df['room_type'] == 'Private room')]
filtro_5

# %%
filtro_6 = df[df['beds'] <= 4]
# filtro_6
