# %% [markdown]
# <a href="https://colab.research.google.com/github/nt189/Entendimiento-de-los-Datos-/blob/main/Actividad_2_3_(Evaluacion).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('listings.csv')

# %%
regunc = df['host_name'].drop_duplicates().head(5)
filtro_1 = df[df['host_name'].isin(regunc)]
filtro_1.to_csv('filtro_1.csv', index=False)

# %%
# filtro_2 =

# %%
filtro_3 = df[df['host_response_time'] == 'within a day']
filtro_3.to_csv('filtro_3.csv', index=False)

# %%
filtro_4 = df[df['accommodates'] >= 5]
filtro_4.to_csv('filtro_4.csv', index=False)

# %%
filtro_5 = df[(df['room_type'] == 'Entire home') | (df['room_type'] == 'Private room')]
filtro_5
# Out:
#                         id                                       listing_url  \
# 3       850744632375448560   https://www.airbnb.com/rooms/850744632375448560
# 5      1082614257267236225  https://www.airbnb.com/rooms/1082614257267236225
# 10                53405110             https://www.airbnb.com/rooms/53405110
# 21                51254530             https://www.airbnb.com/rooms/51254530
# 32     1124112027482881864  https://www.airbnb.com/rooms/1124112027482881864
# ...                    ...                                               ...
# 45520   560162340399438701   https://www.airbnb.com/rooms/560162340399438701
# 45522  1224871364424033713  https://www.airbnb.com/rooms/1224871364424033713
# 45524   808248038370480439   https://www.airbnb.com/rooms/808248038370480439
# 45525   889361677833868590   https://www.airbnb.com/rooms/889361677833868590
# 45530   746345243817423719   https://www.airbnb.com/rooms/746345243817423719
#
# ...

# %%
filtro_6 = df[df['beds'] <= 4]
filtro_6.to_csv('filtro_6.csv', index=False)

# %%
filtro_7 = df[(df['bathrooms'] == 1) | (df['host_is_superhost'] == 't')]
filtro_7 = filtro_7[filtro_7['instant_bookable'] == 't']
filtro_7.to_csv('filtro_7.csv', index=False)

# %%
filtro_8 = df[df['host_has_profile_pic'] == 't']
filtro_8.to_csv('filtro_8.csv', index=False)

# %%
filtro_9 = df[(df['review_scores_cleanliness'] < 3) & (df['review_scores_rating'] > 3)]
filtro_9.to_csv('filtro_9.csv', index=False)
